# %% [markdown]
# # U-Net Stage 1: Mask Preparation & Verification
# ### Sea Sentinel — AI-Powered Underwater Debris & Anomaly Detection
# ---

# %% [markdown]
# ## U-Net Stage 1: Semantic Mask Preparation & Integrity Check
# Synchronizes binary ground truth masks with input sonar rasters.

# %%
from pathlib import Path
import cv2
import numpy as np

PROJECT_ROOT = Path("../..").resolve()
print("U-Net mask preprocessing ready.")
